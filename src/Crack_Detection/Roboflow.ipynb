# %%
# !pip install inference_sdk
from inference_sdk import InferenceHTTPClient
from google.colab import files
# Out:
# ...
#      <input type="file" id="files-8b0f615d-4cf5-4bd4-9f91-0f657cb94242" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b0f615d-4cf5-4bd4-9f91-0f657cb94242">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import cv2
import numpy as np
import json
import matplotlib.pyplot as plt
from google.colab import files
import base64
import requests
import time

# %%
# !pip install inference-cli && inference server start
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 4.0 MB/s eta 0:00:00
# ...
#   Created wheel for pybase64: filename=pybase64-1.0.2-cp311-cp311-linux_x86_64.whl size=146789 sha256=4aa652631c8186b591bf00bec4df833ee71ae9e78b62c58f5be10f2854ffd7a9
#   Stored in directory: /root/.cache/pip/wheels/3d/c0/15/5e79fe7fd3f97ebaf4c080e7c337fb06c1d01bc61905dcb26b
# ...

# %%
'''
uploaded = files.upload()  # Opens a file upload dialog
image_path = list(uploaded.keys())[0]

# create an inference client
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="QUpjB0ciIQyTjsncTk8W"
)

# Run inference
response = CLIENT.infer(
    image_path,
    model_id="crack-detection-using-instance-segmentation-in-yolov8-i9k9l/1"
)

'''
from google.colab.patches import cv2_imshow
# load config

ROBOFLOW_API_KEY = "QUpjB0ciIQyTjsncTk8W"
ROBOFLOW_MODEL = "Crack Detection using Instance Segmentation in YOLOv8 1"
ROBOFLOW_SIZE = 640

FRAMERATE = 30
BUFFER = 6



# Construct the Roboflow Infer URL
# (if running locally replace https://detect.roboflow.com/ with eg http://127.0.0.1:9001/)
upload_url = "".join([
    "https://detect.roboflow.com/",
    ROBOFLOW_MODEL,
    "?api_key=",
    ROBOFLOW_API_KEY,
    "&format=image",
    "&stroke=5"
])

# Get webcam interface via opencv-python
video = cv2.VideoCapture(0)

# Infer via the Roboflow Infer API and return the result
def infer():
    # Get the current image from the webcam
    ret, img = video.read()
    print(ret)

    # Resize (while maintaining the aspect ratio) to improve speed and save bandwidth
    height, width, channels = img.shape
    scale = ROBOFLOW_SIZE / max(height, width)
    img = cv2.resize(img, (round(scale * width), round(scale * height)))

    # Encode image to base64 string
    retval, buffer = cv2.imencode('.jpg', img)
    img_str = base64.b64encode(buffer)

    # Get prediction from Roboflow Infer API
    resp = requests.post(upload_url, data=img_str, headers={
        "Content-Type": "application/x-www-form-urlencoded"
    }, stream=True).raw

    # Parse result image
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)

    return image

# Main loop; infers sequentially until you press "q"
while 1:
    # On "q" keypress, exit
    if(cv2.waitKey(1) == ord('q')):
        break

    # Capture start time to calculate fps
    start = time.time()

    # Synchronously get a prediction from the Roboflow Infer API
    image = infer()
    # And display the inference results
    cv2.imshow('image', image)

    # Print frames per second
    print((1/(time.time()-start)), " fps")

# Release resources when finished
video.release()
cv2.destroyAllWindows()
# Out:
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c68c51fdbaca> in <cell line: 0>()
#      78
#      79     # Synchronously get a prediction from the Roboflow Infer API
# ---> 80     image = infer()
#      81     # And display the inference results
#      82     cv2.imshow('image', image)
#
# <ipython-input-10-c68c51fdbaca> in infer()
#      49
#      50     # Resize (while maintaining the aspect ratio) to improve speed and save bandwidth
# ---> 51     height, width, channels = img.shape
#      52     scale = ROBOFLOW_SIZE / max(height, width)
#      53     img = cv2.resize(img, (round(scale * width), round(scale * height)))
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-74731fb4485e> in <cell line: 0>()
#      12 for detection in result.get("predictions", []):
#      13     if detection.get("class") == "crack":  # Ensure the detected class is "crack"
# ---> 14         points = np.array(detection["points"], np.int32)
#      15         points = points.reshape((-1, 1, 2))
#      16         cv2.fillPoly(mask, [points], (255, 0, 0))  # Fill detected region in blue
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'dict'
